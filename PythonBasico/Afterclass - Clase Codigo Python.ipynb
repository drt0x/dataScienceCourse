# %%
# for 1 a 1000:
    #tarea optimizar un parametro en 1000 corridas.
    #contador 1, 2, 3, 4...., 1000
    #alerta cada 100 casos

# %%
start = 0
stop = 1000
step = 1

a = range(start, stop, step)

# %%
type(a)
# Out:
# range

# %%
for i in a:
    # Proceso corriendo.
    modulo_contador = i % 100
    if modulo_contador == 0:
        print("El proceso corrio con exito la iteracion: " + str(i) + ".")
        
print("El proceso finalizo.")
# Out:
# El proceso corrio con exito la iteracion: 0.
# El proceso corrio con exito la iteracion: 100.
# El proceso corrio con exito la iteracion: 200.
# El proceso corrio con exito la iteracion: 300.
# El proceso corrio con exito la iteracion: 400.
# El proceso corrio con exito la iteracion: 500.
# El proceso corrio con exito la iteracion: 600.
# El proceso corrio con exito la iteracion: 700.
# El proceso corrio con exito la iteracion: 800.
# El proceso corrio con exito la iteracion: 900.
# El proceso finalizo.

# %%
a = range(500, 5000, 20)
for i in a:
    print(i)
# Out:
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# 3000
# 3020
# 3040
# 3060
# 3080
# 3100
# 3120
# 3140
# 3160
# 3180
# 3200
# 3220
# 3240
# 3260
# 3280
# 3300
# 3320
# 3340
# 3360
# 3380
# 3400
# ...

# %%
rango = range(500, 5000, 20)
largo_rango = len(rango)

print("Vamos a correr un proceso por: "+str(largo_rango)+" iteraciones.")

i_contador = 0
for i_parametro in rango:
    # Proceso corriendo (Por ejemplo, entreno un modelo y veo como funciona).
    # print(i_parametro)
    i_contador += 1
    modulo_contador = i_contador % 100
    if modulo_contador == 0:
        print("El proceso corrio con exito la iteracion: " + str(i_contador) + ".")

print("El proceso finalizo.")
# Out:
# Vamos a correr un proceso por: 225 iteraciones.
# El proceso corrio con exito la iteracion: 100.
# El proceso corrio con exito la iteracion: 200.
# El proceso finalizo.
